# %%
import pandas as pd
from imdb import IMDb
import seaborn as sns
import numpy as np

# %%
rating = pd.read_csv("C:/Movie Lens/ml-20m/ratings.csv")

# %%
rating.shape
# Out:
# (20000263, 4)

# %%
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
rating.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
movies = pd.read_csv("C:/Movie Lens/ml-20m/genome-scores.csv")

# %%
movies.shape
# Out:
# (11709768, 3)

# %%
movies.columns
# Out:
# Index(['movieId', 'tagId', 'relevance'], dtype='object')

# %%
ia  = IMDb()

# %%
the_matrix = ia.get_movie('0133093')

# %%
for director in the_matrix['directors']:
    print(director['name'])
# Out:
# Lana Wachowski
# Lilly Wachowski

# %%
print(sorted(the_matrix.keys()))
# Out:
# ['akas', 'animation department', 'art department', 'art directors', 'aspect ratio', 'assistant directors', 'box office', 'camera department', 'canonical title', 'cast', 'casting department', 'casting directors', 'certificates', 'cinematographers', 'color info', 'composers', 'costume departmen', 'costume designers', 'countries', 'country codes', 'cover url', 'director', 'directors', 'distributors', 'editorial department', 'editors', 'full-size cover url', 'genres', 'kind', 'language codes', 'languages', 'location management', 'long imdb canonical title', 'long imdb title', 'make up department', 'miscellaneous', 'music department', 'original air date', 'other companies', 'plot', 'plot outline', 'producers', 'production companies', 'production designers', 'production managers', 'rating', 'runtimes', 'script department', 'set decorators', 'smart canonical title', 'smart long imdb canonical title', 'sound department', 'sound mix', 'special effects', 'special effects companies', 'stunts', 
# ...

# %%
print(ia.get_movie_infoset())
# Out:
# ['airing', 'akas', 'alternate versions', 'awards', 'connections', 'crazy credits', 'critic reviews', 'episodes', 'external reviews', 'external sites', 'faqs', 'full credits', 'goofs', 'keywords', 'locations', 'main', 'misc sites', 'news', 'official sites', 'parents guide', 'photo sites', 'plot', 'quotes', 'release dates', 'release info', 'reviews', 'sound clips', 'soundtrack', 'synopsis', 'taglines', 'technical', 'trivia', 'tv schedule', 'video clips', 'vote details']

# %%
ia.update(the_matrix, ['technical'])

# %%
print(the_matrix.infoset2keys['technical'])
# Out:
# ['tech']

# %%
print(the_matrix.get('tech'))
# Out:
# {'sound mix': ['DTS (Digital DTS Sound)', 'Dolby Digital', 'SDDS', 'Dolby Atmos'], 'printed film format': ['35 mm (anamorphic) (Kodak Vision 2383)'], 'color': ['Color'], 'negative format': ['35 mm (also horizontal) (Kodak Vision 200T 5274, Vision 500T 5279, Vision 800T 5289)'], 'camera': ['Panavision Panaflex Platinum, Panavision Primo Lenses', 'Panavision Panastar, Panavision Primo Lenses', 'Photosonics Camera'], 'aspect ratio': ['2.39 : 1'], 'runtime': ['2 hr 16 min (136 min)'], 'laboratory': ['Technicolor, Hollywood (CA), USA (prints)', 'Atlab Film Laboratory Service, Sydney, Australia (color)'], 'film length': ['3,735 m (Sweden)'], 'cinematographic process': ['Super 35', 'VistaVision (effects shots)']}

# %%
rating.isna().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
values = rating['rating'] == 2.0

# %%
len(rating[values])
# Out:
# 1430997

# %%
rating.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %%
number_users = rating.userId.unique().shape[0]

# %%
number_users
# Out:
# 138493

# %%
number_movie = rating.movieId.unique().shape[0]

# %%
number_movie
# Out:
# 26744

# %%
movies.head(10)
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675
# 5        1      6    0.21700
# 6        1      7    0.06700
# 7        1      8    0.26275
# 8        1      9    0.26200
# 9        1     10    0.03200

# %%
tags = pd.read_csv("C:/Movie Lens/ml-20m/tags.csv")

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
timestamps = tags.timestamp

# %%
(timestamps/(3600*24*365)).head()
# Out:
# 0    39.339079
# 1    43.383754
# 2    43.383754
# 3    43.383751
# 4    43.383754
# Name: timestamp, dtype: float64

# %%
Year = 1970 + round(timestamps/(3600*24*365))

# %%
Year.head()
# Out:
# 0    2009.0
# 1    2013.0
# 2    2013.0
# 3    2013.0
# 4    2013.0
# Name: timestamp, dtype: float64

# %%
Release_Year = Year.astype('int')

# %%
tags = pd.concat([tags,Release_Year],axis=1)

# %%
tags.head(50)
# Out:
#     userId  movieId                                 tag   timestamp  timestamp
# 0       18     4141                         Mark Waters  1240597180       2009
# 1       65      208                           dark hero  1368150078       2013
# 2       65      353                           dark hero  1368150079       2013
# 3       65      521                       noir thriller  1368149983       2013
# 4       65      592                           dark hero  1368150078       2013
# 5       65      668                           bollywood  1368149876       2013
# 6       65      898                    screwball comedy  1368150160       2013
# 7       65     1248                       noir thriller  1368149983       2013
# 8       65     1391                                mars  1368150055       2013
# 9       65     1617                            neo-noir  1368150217       2013
# 10      65     1694                               jesus  1368149925       2013
# ...

# %%
tags.head(10)
# Out:
#    userId  movieId               tag   timestamp  timestamp
# 0      18     4141       Mark Waters  1240597180       2009
# 1      65      208         dark hero  1368150078       2013
# 2      65      353         dark hero  1368150079       2013
# 3      65      521     noir thriller  1368149983       2013
# 4      65      592         dark hero  1368150078       2013
# 5      65      668         bollywood  1368149876       2013
# 6      65      898  screwball comedy  1368150160       2013
# 7      65     1248     noir thriller  1368149983       2013
# 8      65     1391              mars  1368150055       2013
# 9      65     1617          neo-noir  1368150217       2013

# %%
movies1 = ia.search_movie('matrix')
movies1[0:]
# Out:
# [<Movie id:0133093[http] title:_The Matrix (1999)_>,
#  <Movie id:0106062[http] title:_"Matrix" (1993)_>,
#  <Movie id:5274778[http] title:_"Merci Qui?" Matrix (2009)_>,
#  <Movie id:0234215[http] title:_The Matrix Reloaded (2003)_>,
#  <Movie id:0242653[http] title:_The Matrix Revolutions (2003)_>,
#  <Movie id:0295432[http] title:_The Matrix Revisited (2001) (V)_>,
#  <Movie id:0270841[http] title:_Cyber Wars (2004)_>,
#  <Movie id:1842414[http] title:_Matrix IV (2010)_>,
#  <Movie id:10838180[http] title:_The Matrix 4 (2022)_>,
#  <Movie id:9642498[http] title:_The Matrix (2016)_>,
#  <Movie id:0328832[http] title:_The Animatrix (2003) (V)_>,
#  <Movie id:0364888[http] title:_"Threat Matrix" (2003)_>,
#  <Movie id:0277828[http] title:_Enter the Matrix (2003) (VG)_>,
#  <Movie id:9851526[http] title:_The Matrix (2004)_>,
#  <Movie id:6301452[http] title:_Matriarch (I) (2018)_>,
#  <Movie id:0390244[http] title:_The Matrix Online (2005) (VG)_>,
# ...

# %%
ia.get_movie_infoset()
# Out:
# ['airing',
#  'akas',
#  'alternate versions',
#  'awards',
#  'connections',
#  'crazy credits',
#  'critic reviews',
#  'episodes',
#  'external reviews',
#  'external sites',
#  'faqs',
#  'full credits',
#  'goofs',
#  'keywords',
#  'locations',
#  'main',
#  'misc sites',
#  'news',
#  'official sites',
#  'parents guide',
#  'photo sites',
#  'plot',
#  'quotes',
#  'release dates',
#  'release info',
#  'reviews',
#  'sound clips',
#  'soundtrack',
#  'synopsis',
#  'taglines',
#  'technical',
#  'trivia',
#  'tv schedule',
#  'video clips',
#  'vote details']

# %%
#moves = tags['movieId']
moves = tags['movieId'][0:50]
movie_names = []
genres_movie = []
for item in moves:
    movie = ia.get_movie(item)
    movie_name = movie.get('title')
    genres = movie.get('genres')
    genres_movie.append(genres)
    movie_names.append(movie_name)
print(movie_names)    
movie_names_series = pd.Series(movie_names)
tags['Movie_Name'] =  movie_names_series
genres_series = pd.Series(genres_movie)
tags['Genre'] = genres_series
# Out:
# ['Im Schützengraben', 'The Miller and Chimney Sweep', 'Execution of Czolgosz with Panorama of Auburn Prison', 'The Little Train Robbery', 'Eureka Stockade', 'The Count of Monte Cristo', 'His Lost Love', 'His Last Burglary', 'The Seal of the Church', "The Fisherman's Daughter", 'In Old California When the Gringos Came', 'The Millionaire and the Squatter', 'Anfisa', 'For the Honor of the Name', 'A Matter of Business', 'Barnet', "By Man's Law", 'False to Their Trust', 'The Last Blockhouse', 'Cora', 'The Committee on Credentials', 'The Isle of Life', "Mammy's Rose", 'The Secret of the Swamp', 'Sacrifice', 'The Spreading Dawn', 'Irma la mala', 'Forbidden Music', 'Flickan i regnet', 'Flickan i regnet', 'Luna de verano', 'Three Outlaw Samurai', 'Three Outlaw Samurai', 'Three Outlaw Samurai', 'Three Outlaw Samurai', 'The Young Girls Turn 25', 'The Young Girls Turn 25', 'The Young Girls Turn 25', 'The Young Girls Turn 25', 'The Young Girls Turn 25', 'The Young Girls Turn 25', 'The Young Girls
# ...

# %%
movie_names_series
# Out:
# 0                                     Im Schützengraben
# 1                          The Miller and Chimney Sweep
# 2     Execution of Czolgosz with Panorama of Auburn ...
# 3                              The Little Train Robbery
# 4                                       Eureka Stockade
# 5                             The Count of Monte Cristo
# 6                                         His Lost Love
# 7                                     His Last Burglary
# 8                                The Seal of the Church
# 9                              The Fisherman's Daughter
# 10              In Old California When the Gringos Came
# 11                     The Millionaire and the Squatter
# 12                                               Anfisa
# 13                            For the Honor of the Name
# 14                                 A Matter of Business
# 15                                               Barnet
# 16                                         By Man's Law
# ...

# %%
genres_series.head()
# Out:
# 0                                       None
# 1                            [Comedy, Short]
# 2                    [Short, Drama, History]
# 3    [Short, Action, Crime, Family, Western]
# 4                                    [Short]
# dtype: object

# %%
tags.head(50)
# Out:
#     userId  movieId                                 tag   timestamp  \
# 0       18     4141                         Mark Waters  1240597180
# 1       65      208                           dark hero  1368150078
# 2       65      353                           dark hero  1368150079
# 3       65      521                       noir thriller  1368149983
# 4       65      592                           dark hero  1368150078
# 5       65      668                           bollywood  1368149876
# 6       65      898                    screwball comedy  1368150160
# 7       65     1248                       noir thriller  1368149983
# 8       65     1391                                mars  1368150055
# 9       65     1617                            neo-noir  1368150217
# 10      65     1694                               jesus  1368149925
# 11      65     1783                       noir thriller  1368149983
# 12      65     2022                               jesus  1368149925
# ...

# %%
moves
# Out:
# 0       4141
# 1        208
# 2        353
# 3        521
# 4        592
# 5        668
# 6        898
# 7       1248
# 8       1391
# 9       1617
# 10      1694
# 11      1783
# 12      2022
# 13      2193
# 14      2353
# 15      2662
# 16      2726
# 17      2840
# 18      3052
# 19      5135
# 20      6539
# 21      6874
# 22      7013
# 23      7318
# 24      8529
# 25      8622
# 26     27803
# 27     27866
# 28     48082
# 29     48082
# 30     51884
# 31     58652
# 32     58652
# 33     58652
# 34     58652
# 35    106696
# 36    106696
# 37    106696
# 38    106696
# 39    106696
# 40    106696
# 41    106696
# 42    106696
# 43    106696
# 44    106696
# 45    106696
# 46    106696
# 47    106696
# 48    106696
# 49    106696
# Name: movieId, dtype: int64

# %%
rating_1000 = rating[0:1000]

# %%
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
movies.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675
